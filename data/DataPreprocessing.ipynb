# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('SlaughterCounts.csv')

# Change dash in data to space
data['Date'] = data['Date'].str.replace('-',' ')

# Update column counts
columns = data.columns
for column in columns:
    if column != 'Date':
        if data[column].dtype != np.number:
            data[column] = data[column].str.replace(',', '')
        
        data[column] = pd.to_numeric(data[column])
        
        data[column] = data[column] * 1000
        
data = data.fillna(0.0)

data
# Out:
#          Date     Cattle     Steers   Heifers  Beef cows  Dairy cows  \
# 0    Sep 2019  2676700.0  1278200.0  830800.0   258300.0    259700.0
# 1    Aug 2019  2926200.0  1462100.0  878100.0   265300.0    270200.0
# 2    Jul 2019  2938300.0  1511300.0  852900.0   266400.0    260000.0
# 3    Jun 2019  2804900.0  1475400.0  783100.0   262300.0    234200.0
# 4    May 2019  2939000.0  1544000.0  812900.0   271700.0    261600.0
# ..        ...        ...        ...       ...        ...         ...
# 904  May 1944        0.0        0.0  123600.0        0.0         0.0
# 905  Apr 1944        0.0        0.0  137100.0        0.0         0.0
# 906  Mar 1944        0.0        0.0  158800.0        0.0         0.0
# 907  Feb 1944        0.0        0.0  170500.0        0.0         0.0
# 908  Jan 1944        0.0        0.0  194700.0        0.0         0.0
#
#      Bulls and stags   Calves        Hogs  Barrows and gilts       Sows  \
# ...

# %%
# Create main data json file
data.to_json('SlaughterCounts.json', orient='records')

# %%
# Now get the total sums
year_data = data

# %%
year_data['Date'].str.contains('2019')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 904    False
# 905    False
# 906    False
# 907    False
# 908    False
# Name: Date, Length: 909, dtype: bool

# %%
for i in range(1940, 2020):
    print(str(i))
# Out:
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
